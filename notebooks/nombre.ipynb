# %%
from cloudant.client import Cloudant
from cloudant.error import CloudantException
from cloudant.result import Result, ResultByKey

# %%
ACCOUNT_NAME = "Cotizacion-dolar-EMMA-1"
API_KEY = "9HayqJD8RCe83zJ2kizNRsncXhTf7rjshE7Gr3SQZksQ"


client = Cloudant.iam(ACCOUNT_NAME, API_KEY, connect=True)
client.connect()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\005184613\AppData\Local\Programs\Python\Python38\lib\site-packages\cloudant\_client_session.py:220, in IAMSession.login(self)
#     219 try:
# --> 220     super(IAMSession, self).request(
#     221         'POST',
#     222         self._session_url,
#     223         headers={'Content-Type': 'application/json'},
#     224         data=json.dumps({'access_token': access_token})
#     225     ).raise_for_status()
#     227 except RequestException:
#
# File c:\Users\005184613\AppData\Local\Programs\Python\Python38\lib\site-packages\requests\models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 410 Client Error: Gone for url: https://cotizacion-dolar-emma-1.cloudant.com/_iam_session
#
# ...

# %%
ACCOUNT_NAME = "https://75c34b90-392e-4188-9060-cbeaa04626e8-bluemix.cloudantnosqldb.appdomain.cloud"
API_KEY = "9HayqJD8RCe83zJ2kizNRsncXhTf7rjshE7Gr3SQZksQ"


client = Cloudant.iam(ACCOUNT_NAME, API_KEY, connect=True)
client.connect()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\Users\005184613\AppData\Local\Programs\Python\Python38\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File c:\Users\005184613\AppData\Local\Programs\Python\Python38\lib\site-packages\urllib3\util\connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# ...

# %%
for indice in range(df.s)
